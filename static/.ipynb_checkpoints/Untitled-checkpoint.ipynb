# %%
from PIL import Image

# %%
image = Image.open('about1.jpg')

# %%
image
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=275x183>

# %%
new=image.resize((600,700))

# %%
new.save("tas.jpg")
